# %% [markdown]
# # Mein erstes Jupyter Notebook

# %% [markdown]
# Wir wollen die Daten vom [Environmental Justice Atlas](https://ejatlas.org/) in dieses Notebook laden und anschließend ein paar Analysen rechnen.
#
# Dafür müssen wir als erstes ein paar Bibliotheken importieren, die wir benutzen werden.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Jetzt machen wir uns auf die Suche nach unserem Datensatz und importieren ihn anschließend. Entweder als .csv-Datei, oder direkt live von ejatlas.org.

# %%
import csv-file 
# funktioniert so natürlich noch nicht. Code muss hier noch angepasst werden.

# %% [markdown]
# ## Altes Beispiel
#
# Hier ist noch ein Plotbeispiel aus einer vorherigen Version dieses Notebooks. Hier müssen wir noch weiter umbauen. Dort wird zunächst eine Funktion mit einem Parameter **a** definiert.

# %%
a = 2;
x = np.linspace(0, 10*np.pi, 10**3);
y = np.sin(a*x) + np.cos(x);

# %% [markdown]
# und anschließend in einen ganz normalen Lineplot geladen:

# %%
plt.plot(x,y);
plt.title('mein erster Plot');
